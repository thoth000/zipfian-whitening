# %% [markdown]
# Generate tables for static word embeddings related experiments.

# %%
import os
import pandas as pd
import json

def get_score(model_name, pooling_name, task):
    root_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
    path = os.path.join(root_path, "results", model_name, task, pooling_name , f"{task}.json")
    with open(path, "r") as f:
        data = json.load(f)
    return data['validation'][sim][cor] if task == "JSTS" else data['test'][sim][cor]

sim = "cos_sim"
cor = "spearman"

# example usage
get_score("GoogleNews-vectors-negative300-torch", "uniform_whitening/uniform_centering_then_zipfian_whitening_norm", "STS12")
# Out:
# 0.5901050766815591

# %%
def create_pandas_tables(model_names, pooling_names, tasks):
    """
    Creates a dictionary of pandas DataFrames, one per model_name.
    Each DataFrame has:
      - Rows indexed by pooling_names (in the given order).
      - Columns = tasks list + 'Average' column.
    """
    results = {}
    for model_name in model_names:
        # Collect scores in a 2D list where each row corresponds
        # to a specific pooling_name, and each column to a task.
        table_data = []
        for pooling_name in pooling_names:
            row_scores = []
            for task in tasks:
                score = get_score(model_name, pooling_name, task)
                row_scores.append(score)
            table_data.append(row_scores)

        # Create a DataFrame from the collected data
        df = pd.DataFrame(table_data, index=pooling_names, columns=tasks)
        # Calculate the average score across all tasks
        df["Average"] = df.mean(axis=1)
        # (Optional) name your index for clarity
        df.index.name = "Pooling Name"

        df = df.mul(100).round(2)

        results[model_name] = df

    return results

# %% [markdown]
# # Table 8 (enwiki)

# %%
model_names = [
    "GoogleNews-vectors-negative300-torch", # word2vec
    "average_word_embeddings_glove.840B.300d", # glove
    "fasttext-en-torch",
    "fasttext-en-subword-torch",
]

pooling_names = [
    "normal/mean",
    "uniform_whitening/centering_only",
    "uniform_whitening/whitening",
    "zipfian_whitening/centering_only",
    "zipfian_whitening/whitening",
    "abtp/component_removal",
    "sif/sif_w_component_removal",
]

tasks = [
    "STS12",
    "STS13",
    "STS14",
    "STS15",
    "STS16",
    "SICK-R",
    "STSBenchmark",
]

sim = "cos_sim"
cor = "spearman"

all_results = create_pandas_tables(model_names, pooling_names, tasks)

# %%
# glove
all_results["average_word_embeddings_glove.840B.300d"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       56.46  50.41  51.13  58.60  49.03   57.01
# uniform_whitening/centering_only  55.54  46.32  49.67  56.03  46.90   56.44
# uniform_whitening/whitening       53.31  62.45  57.93  68.68  58.69   57.92
# zipfian_whitening/centering_only  54.52  69.20  60.87  69.82  62.61   58.01
# zipfian_whitening/whitening       57.76  72.22  67.04  76.80  71.72   61.80
# abtp/component_removal            52.67  67.38  59.40  69.53  60.71   58.56
# sif/sif_w_component_removal       60.23  68.78  62.39  67.26  61.85   56.91
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              46.17    52.69
# uniform_whitening/centering_only         45.17    50.87
# uniform_whitening/whitening              52.21    58.74
# zipfian_whitening/centering_only         52.25    61.04
# zipfian_whitening/whitening              66.92    67.75
# abtp/component_removal                   54.28    60.36
# sif/sif_w_component_removal              58.70    62.30

# %%
# word2vec
all_results["GoogleNews-vectors-negative300-torch"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       58.57  68.64  63.65  71.73  61.79   61.77
# uniform_whitening/centering_only  58.17  67.34  62.19  70.15  59.60   61.39
# uniform_whitening/whitening       56.53  66.95  62.77  72.42  61.05   62.74
# zipfian_whitening/centering_only  56.89  69.95  65.08  73.91  65.71   62.18
# zipfian_whitening/whitening       56.16  70.33  67.20  76.60  70.99   62.52
# abtp/component_removal            55.53  69.32  63.13  72.25  60.98   62.02
# sif/sif_w_component_removal       60.05  73.26  66.87  74.32  67.64   59.22
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              56.98    63.30
# uniform_whitening/centering_only         55.85    62.10
# uniform_whitening/whitening              56.03    62.64
# zipfian_whitening/centering_only         58.84    64.65
# zipfian_whitening/whitening              66.50    67.19
# abtp/component_removal                   56.98    62.89
# sif/sif_w_component_removal              63.04    66.34

# %%
# fasttext-en-torch
all_results["fasttext-en-torch"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       57.94  68.97  62.37  72.26  63.59   59.99
# uniform_whitening/centering_only  59.73  55.02  55.16  64.22  53.39   58.85
# uniform_whitening/whitening       52.47  59.01  53.90  65.33  52.61   58.34
# zipfian_whitening/centering_only  58.30  71.69  64.57  74.10  67.59   60.75
# zipfian_whitening/whitening       58.86  73.85  68.43  78.07  74.00   62.85
# abtp/component_removal            58.35  69.09  60.82  71.99  60.76   60.34
# sif/sif_w_component_removal       61.54  76.95  68.39  76.98  70.27   59.52
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              59.82    63.56
# uniform_whitening/centering_only         52.46    56.98
# uniform_whitening/whitening              48.60    55.75
# zipfian_whitening/centering_only         59.40    65.20
# zipfian_whitening/whitening              69.55    69.37
# abtp/component_removal                   57.02    62.62
# sif/sif_w_component_removal              67.08    68.67

# %%
# fasttext-en-subword-torch
all_results["fasttext-en-subword-torch"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       49.10  47.34  51.94  61.99  51.54   53.60
# uniform_whitening/centering_only  49.21  43.13  49.89  62.03  49.70   54.56
# uniform_whitening/whitening       45.12  41.00  47.30  62.08  48.85   54.80
# zipfian_whitening/centering_only  48.68  55.03  54.07  60.23  58.41   54.64
# zipfian_whitening/whitening       61.22  60.68  63.18  73.59  69.87   59.82
# abtp/component_removal            49.64  41.79  48.81  60.84  47.57   55.09
# sif/sif_w_component_removal       57.28  54.50  60.77  68.82  61.63   56.83
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              50.43    52.28
# uniform_whitening/centering_only         46.91    50.78
# uniform_whitening/whitening              43.55    48.96
# zipfian_whitening/centering_only         50.38    54.49
# zipfian_whitening/whitening              68.20    65.22
# abtp/component_removal                   44.23    49.71
# sif/sif_w_component_removal              60.36    60.03

# %% [markdown]
# # Table 9 (test set frequency)

# %%
model_names = [
    "GoogleNews-vectors-negative300-torch_in_batch",
    "average_word_embeddings_glove.840B.300d_in_batch", 
    "fasttext-en-torch_in_batch",
    "fasttext-en-subword-torch_in_batch",
]

pooling_names = [
    "normal/mean",
    "uniform_whitening/centering_only",
    "uniform_whitening/whitening",
    "zipfian_whitening/centering_only",
    "zipfian_whitening/whitening",
    "abtp/component_removal",
]

tasks = [
    "STS12",
    "STS13",
    "STS14",
    "STS15",
    "STS16",
    "SICK-R",
    "STSBenchmark",
]

sim = "cos_sim"
cor = "spearman"

all_results = create_pandas_tables(model_names, pooling_names, tasks)

# %%
# glove
all_results["average_word_embeddings_glove.840B.300d_in_batch"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       57.71  50.29  50.61  58.38  48.76   56.76
# uniform_whitening/centering_only  56.32  61.17  52.68  64.80  55.80   57.98
# uniform_whitening/whitening       51.67  60.94  57.14  70.09  63.08   55.14
# zipfian_whitening/centering_only  50.69  70.66  61.59  70.19  68.25   60.03
# zipfian_whitening/whitening       61.63  78.36  69.48  76.83  74.08   60.11
# abtp/component_removal            52.93  66.93  60.10  71.93  63.12   58.23
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              46.22    52.67
# uniform_whitening/centering_only         47.94    56.67
# uniform_whitening/whitening              53.16    58.74
# zipfian_whitening/centering_only         56.64    62.58
# zipfian_whitening/whitening              71.60    70.30
# abtp/component_removal                   53.72    60.99

# %%
# word2vec
all_results["GoogleNews-vectors-negative300-torch_in_batch"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       59.00  68.92  63.99  72.51  62.25   61.87
# uniform_whitening/centering_only  57.88  70.34  64.24  74.71  65.57   62.47
# uniform_whitening/whitening       58.45  69.42  65.46  76.43  67.78   62.87
# zipfian_whitening/centering_only  55.02  71.47  65.81  74.36  69.52   62.92
# zipfian_whitening/whitening       59.37  76.92  69.48  76.42  73.56   60.07
# abtp/component_removal            56.33  70.42  64.71  74.74  65.19   62.55
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              57.15    63.67
# uniform_whitening/centering_only         58.09    64.76
# uniform_whitening/whitening              60.85    65.89
# zipfian_whitening/centering_only         61.02    65.73
# zipfian_whitening/whitening              70.42    69.46
# abtp/component_removal                   58.21    64.59

# %%
# fasttext-en-torch
all_results["fasttext-en-torch_in_batch"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       58.23  69.36  62.89  73.09  64.25   60.22
# uniform_whitening/centering_only  60.60  69.51  61.09  73.92  64.49   61.14
# uniform_whitening/whitening       55.56  63.51  57.73  70.68  62.40   57.93
# zipfian_whitening/centering_only  55.92  73.36  65.72  74.12  72.18   62.30
# zipfian_whitening/whitening       62.20  79.35  71.03  77.95  76.28   60.66
# abtp/component_removal            59.13  71.00  63.30  74.80  65.96   61.69
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              60.27    64.04
# uniform_whitening/centering_only         57.42    64.02
# uniform_whitening/whitening              54.65    60.35
# zipfian_whitening/centering_only         62.95    66.65
# zipfian_whitening/whitening              73.56    71.58
# abtp/component_removal                   58.23    64.87

# %%
# fasttext-en-subword-torch
all_results["fasttext-en-subword-torch_in_batch"]
# Out:
#                                   STS12  STS13  STS14  STS15  STS16  SICK-R  \
# Pooling Name
# normal/mean                       51.37  51.49  54.57  62.75  52.97   53.53
# uniform_whitening/centering_only  51.31  44.80  49.66  62.27  47.43   54.86
# uniform_whitening/whitening       51.52  49.33  53.51  68.28  58.34   56.94
# zipfian_whitening/centering_only  43.15  53.40  53.67  63.05  59.09   56.57
# zipfian_whitening/whitening       60.87  72.21  67.79  75.86  73.88   60.52
# abtp/component_removal            49.06  45.16  49.57  62.14  50.75   55.49
#
#                                   STSBenchmark  Average
# Pooling Name
# normal/mean                              52.41    54.16
# uniform_whitening/centering_only         43.12    50.49
# uniform_whitening/whitening              51.69    55.66
# zipfian_whitening/centering_only         47.16    53.73
# zipfian_whitening/whitening              70.99    68.87
# abtp/component_removal                   44.53    50.96

# %% [markdown]
# # Table 10 (JSTS)

# %%
# Wiki frequency
model_names = [
    "fasttext-ja-torch"
]

pooling_names = [
    "normal/mean",
    "uniform_whitening/centering_only",
    "uniform_whitening/whitening",
    "zipfian_whitening/centering_only",
    "zipfian_whitening/whitening",
    "abtp/component_removal",
    "sif/sif_w_component_removal",
]

tasks = [
    "JSTS"
]

sim = "cos_sim"
cor = "spearman"

all_results = create_pandas_tables(model_names, pooling_names, tasks)
all_results["fasttext-ja-torch"]
# Out:
#                                    JSTS  Average
# Pooling Name
# normal/mean                       55.81    55.81
# uniform_whitening/centering_only  56.06    56.06
# uniform_whitening/whitening       55.53    55.53
# zipfian_whitening/centering_only  57.55    57.55
# zipfian_whitening/whitening       65.56    65.56
# abtp/component_removal            57.14    57.14
# sif/sif_w_component_removal       61.03    61.03

# %%
# Test set frequency
model_names = [
    "fasttext-ja-torch_in_batch"
]

pooling_names = [
    "normal/mean",
    "uniform_whitening/centering_only",
    "uniform_whitening/whitening",
    "zipfian_whitening/centering_only",
    "zipfian_whitening/whitening",
    "abtp/component_removal",
]

tasks = [
    "JSTS"
]

sim = "cos_sim"
cor = "spearman"

all_results = create_pandas_tables(model_names, pooling_names, tasks)
all_results["fasttext-ja-torch_in_batch"]
# Out:
#                                    JSTS  Average
# Pooling Name
# normal/mean                       59.94    59.94
# uniform_whitening/centering_only  59.89    59.89
# uniform_whitening/whitening       61.75    61.75
# zipfian_whitening/centering_only  63.05    63.05
# zipfian_whitening/whitening       69.86    69.86
# abtp/component_removal            63.02    63.02

# %% [markdown]
# # Table 11 (norm / direction)

# %%
model_names = [
    "GoogleNews-vectors-negative300-torch", # word2vec
    "average_word_embeddings_glove.840B.300d", # glove
    "fasttext-en-torch",
    "fasttext-en-subword-torch",
]

pooling_names = [
    "normal/raw_then_zipfian_whitening_norm",
    "zipfian_whitening/raw_then_zipfian_whitening_dirction",
    "uniform_whitening/uniform_centering_then_zipfian_whitening_norm",
    "uniform_whitening/uniform_whitening_then_zipfian_whitening_norm",
    "zipfian_whitening/zipfian_whitening_then_uniform_centering_norm",
    "zipfian_whitening/zipfian_whitening_then_uniform_whitening_norm",
]

tasks = [
    "STS12",
    "STS13",
    "STS14",
    "STS15",
    "STS16",
    "SICK-R",
    "STSBenchmark",
]

sim = "cos_sim"
cor = "spearman"

all_results = create_pandas_tables(model_names, pooling_names, tasks)

# %%
# glove
# TODO: the current scores in the paper seems to be using pearson correlation, not spearman. check out why.
all_results["average_word_embeddings_glove.840B.300d"]
# Out:
#                                                     STS12  STS13  STS14  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              62.08  66.62  59.34
# zipfian_whitening/raw_then_zipfian_whitening_di...  49.66  64.15  61.73
# uniform_whitening/uniform_centering_then_zipfia...  61.41  63.94  58.33
# uniform_whitening/uniform_whitening_then_zipfia...  60.20  73.63  64.98
# zipfian_whitening/zipfian_whitening_then_unifor...  47.12  61.14  59.42
# zipfian_whitening/zipfian_whitening_then_unifor...  49.57  65.00  62.17
#
#                                                     STS15  STS16  SICK-R  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              65.93  58.57   57.52
# zipfian_whitening/raw_then_zipfian_whitening_di...  71.89  66.37   59.52
# uniform_whitening/uniform_centering_then_zipfia...  63.88  56.90   56.39
# uniform_whitening/uniform_whitening_then_zipfia...  74.21  66.67   60.53
# zipfian_whitening/zipfian_whitening_then_unifor...  70.10  63.46   58.58
# zipfian_whitening/zipfian_whitening_then_unifor...  72.24  67.83   58.22
#
#                                                     STSBenchmark  Average
# Pooling Name
# normal/raw_then_zipfian_whitening_norm                     55.43    60.78
# zipfian_whitening/raw_then_zipfian_whitening_di...         57.20    61.50
# uniform_whitening/uniform_centering_then_zipfia...         54.62    59.35
# uniform_whitening/uniform_whitening_then_zipfia...         61.55    65.97
# zipfian_whitening/zipfian_whitening_then_unifor...         53.87    59.10
# zipfian_whitening/zipfian_whitening_then_unifor...         57.73    61.82

# %%
# word2vec
all_results['GoogleNews-vectors-negative300-torch']
# Out:
#                                                     STS12  STS13  STS14  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              58.87  71.96  65.52
# zipfian_whitening/raw_then_zipfian_whitening_di...  55.45  68.07  66.49
# uniform_whitening/uniform_centering_then_zipfia...  59.01  71.91  65.28
# uniform_whitening/uniform_whitening_then_zipfia...  58.49  71.53  66.22
# zipfian_whitening/zipfian_whitening_then_unifor...  54.94  67.87  66.18
# zipfian_whitening/zipfian_whitening_then_unifor...  53.40  66.91  65.15
#
#                                                     STS15  STS16  SICK-R  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              73.55  66.61   61.05
# zipfian_whitening/raw_then_zipfian_whitening_di...  75.98  68.46   63.41
# uniform_whitening/uniform_centering_then_zipfia...  73.26  65.71   61.34
# uniform_whitening/uniform_whitening_then_zipfia...  75.62  67.82   61.95
# zipfian_whitening/zipfian_whitening_then_unifor...  75.62  68.27   63.11
# zipfian_whitening/zipfian_whitening_then_unifor...  75.11  66.90   63.24
#
#                                                     STSBenchmark  Average
# Pooling Name
# normal/raw_then_zipfian_whitening_norm                     61.59    65.59
# zipfian_whitening/raw_then_zipfian_whitening_di...         63.25    65.87
# uniform_whitening/uniform_centering_then_zipfia...         61.27    65.40
# uniform_whitening/uniform_whitening_then_zipfia...         62.87    66.35
# zipfian_whitening/zipfian_whitening_then_unifor...         62.83    65.55
# zipfian_whitening/zipfian_whitening_then_unifor...         60.95    64.52

# %%
all_results['fasttext-en-torch']
# Out:
#                                                     STS12  STS13  STS14  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              61.35  75.69  66.77
# zipfian_whitening/raw_then_zipfian_whitening_di...  55.12  70.20  66.23
# uniform_whitening/uniform_centering_then_zipfia...  65.26  70.32  63.63
# uniform_whitening/uniform_whitening_then_zipfia...  62.48  76.02  66.73
# zipfian_whitening/zipfian_whitening_then_unifor...  52.86  68.40  64.60
# zipfian_whitening/zipfian_whitening_then_unifor...  46.45  64.51  60.10
#
#                                                     STS15  STS16  SICK-R  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              75.69  69.41   61.24
# zipfian_whitening/raw_then_zipfian_whitening_di...  75.92  71.95   61.57
# uniform_whitening/uniform_centering_then_zipfia...  71.24  62.99   60.34
# uniform_whitening/uniform_whitening_then_zipfia...  76.55  68.65   61.56
# zipfian_whitening/zipfian_whitening_then_unifor...  74.39  70.23   60.92
# zipfian_whitening/zipfian_whitening_then_unifor...  70.59  64.80   58.58
#
#                                                     STSBenchmark  Average
# Pooling Name
# normal/raw_then_zipfian_whitening_norm                     65.31    67.92
# zipfian_whitening/raw_then_zipfian_whitening_di...         65.35    66.62
# uniform_whitening/uniform_centering_then_zipfia...         61.24    65.00
# uniform_whitening/uniform_whitening_then_zipfia...         64.31    68.04
# zipfian_whitening/zipfian_whitening_then_unifor...         62.70    64.87
# zipfian_whitening/zipfian_whitening_then_unifor...         54.87    59.99

# %%
all_results['fasttext-en-subword-torch']
# Out:
#                                                     STS12  STS13  STS14  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              58.03  60.35  60.76
# zipfian_whitening/raw_then_zipfian_whitening_di...  47.65  49.71  55.26
# uniform_whitening/uniform_centering_then_zipfia...  60.29  58.99  61.11
# uniform_whitening/uniform_whitening_then_zipfia...  61.06  60.35  63.07
# zipfian_whitening/zipfian_whitening_then_unifor...  46.17  49.23  54.49
# zipfian_whitening/zipfian_whitening_then_unifor...  43.20  46.68  52.15
#
#                                                     STS15  STS16  SICK-R  \
# Pooling Name
# normal/raw_then_zipfian_whitening_norm              67.99  61.74   56.35
# zipfian_whitening/raw_then_zipfian_whitening_di...  67.96  61.81   56.62
# uniform_whitening/uniform_centering_then_zipfia...  70.23  65.36   57.78
# uniform_whitening/uniform_whitening_then_zipfia...  74.29  69.19   59.56
# zipfian_whitening/zipfian_whitening_then_unifor...  67.33  61.11   55.95
# zipfian_whitening/zipfian_whitening_then_unifor...  65.46  59.01   54.07
#
#                                                     STSBenchmark  Average
# Pooling Name
# normal/raw_then_zipfian_whitening_norm                     61.47    60.96
# zipfian_whitening/raw_then_zipfian_whitening_di...         54.72    56.25
# uniform_whitening/uniform_centering_then_zipfia...         63.06    62.40
# uniform_whitening/uniform_whitening_then_zipfia...         65.09    64.66
# zipfian_whitening/zipfian_whitening_then_unifor...         53.01    55.33
# zipfian_whitening/zipfian_whitening_then_unifor...         49.26    52.83
